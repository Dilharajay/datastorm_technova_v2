# %%
import pandas as pd

# %%
gold_df = pd.read_parquet("../data/gold/fact_table/data.parquet")

# %%
gold_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
rejects = pd.read_parquet("/home/user/git/comp/datastorm_technova_v2/data/rejects/outlet_coordinates/data.parquet")

# %%
rejects._reject_reason.value_counts()
# Out:
# _reject_reason
# coordinates_out_of_bounds    40
# Name: count, dtype: int64

# %%
trans_reject = pd.read_parquet("/home/user/git/comp/datastorm_technova_v2/data/rejects/transactions_history_final/data.parquet")

# %%
trans_reject._reject_reason.value_counts()
# Out:
# _reject_reason
# negative_volume;negative_bill    4753
# zero_volume                       100
# volume_exceeds_max                  1
# Name: count, dtype: int64
