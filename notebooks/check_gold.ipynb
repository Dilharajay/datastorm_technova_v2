# %%
import pandas as pd

# %%
gold_df = pd.read_parquet("../data/gold/fact_table/data.parquet")

# %%
gold_df.duplicated().sum()

# %%
rejects = pd.read_parquet(
    "../data/rejects/outlet_coordinates/data.parquet"
)

# %%
rejects._reject_reason.value_counts()

# %%
trans_reject = pd.read_parquet(
    "../data/rejects/transactions_history_final/data.parquet"
)

# %%
trans_reject._reject_reason.value_counts()
